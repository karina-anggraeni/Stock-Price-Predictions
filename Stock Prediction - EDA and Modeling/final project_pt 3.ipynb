# %% [markdown]
# ## Final Project: Prediksi Harga Saham Bank di Indonesia

# %% [markdown]
# **Karina Anggraeni - JCDSAH BSD** </br>
# Dataset diambil dari aplikasi Neo HOTS (Mirae Asset Sekuritas)
#
# Data harga saham bank yang digunakan dalam dataset ini adalah data terhadap bank swasta nasional, bank swasta asing, dan bank milik negara, yaitu:
# - Bank Central Asia (BBCA) dan Bank Mega (MEGA) - swasta nasional
# - Bank Woori Saudara (SDRA) dan MayBank (BNII) - swasta asing
# - Bank Rakyat Indonesia (BRII) dan Bank Mandiri (BMRI) - negara

# %% [markdown]
# ### [PART 3: Stock Price Prediction - BBRI]

# %% [markdown]
# ### 4. Modeling and Evaluation

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

import os
from statsmodels.tsa.stattools import adfuller
from IPython.core.debugger import set_trace
from pmdarima.arima.utils import ndiffs
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.models import load_model

from IPython import display

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### B. BBRI Stock Prediction

# %%
bbri = pd.read_csv('../Datasets/df_bbri.csv', index_col = 'Date')

# %%
bbri_train_len = math.ceil(len(bbri)*0.8)
bbri_train_len
# Out:
# 969

# %% [markdown]
# #### B.1. ARIMA Model

# %% [markdown]
# **ADF Stationary Test**

# %% [markdown]
# Augumented Dickey Fuller Test (ADF Test) digunakan untuk memeriksa stationer/ tidaknya suatu data. Test ini biasanya digunakan dalam ARIMA untuk time-series karena model ARIMA akan bekerja lebih baik pada data yang bersifat stationer.

# %%
bbri_adf = adfuller(bbri)

print(f'ADF Statistics: {bbri_adf[0]}')

if bbri_adf[1] > 0.05:
    print(f'p-value: {bbri_adf[1]}, data is stationary.')
else:
    print(f'p-value: {bbri_adf[1]}, data is non-stationary.')
# Out:
# ADF Statistics: -1.2732817558735006
# p-value: 0.6413055936839371, data is stationary.

# %% [markdown]
# Karena nilai p-value dari ADF Test terhadap BBRI melebihi 0.05 (p-value > 0.05), maka dapat disimpulkan data yang kita miliki tidak stationer.

# %% [markdown]
# **Manual Parameter Tuning**

# %% [markdown]
# Pada model ARIMA, terdapat 3 jenis parameter yang dibutuhkan ketika melakukan modeling, yaitu: </br>
# - **p** menyatakan nilai variabel AR (Auto Regressive Variable/ Lag Variable) atau berapa banyak data periode sebelumnya yang akan digunakan dalam feature </br>
# - **d** menyatakan nilai variabel I (Integrated Variable) atau berapa banyak diferensiasi yang perlu dilakukan agar data time-series menjadi stationer </br>
# - **p** menyatakan nilai variabel MA (Moving Average Variable)
#
# Nilai p, d, dan q dapat kita estimasi menggunakan plot ACF dan  PACF.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,4))
bbri['Close'].plot(color = 'steelblue', ax = ax1)
ax1.set_title('BBRI Close Price', size = 20)
ax1.grid()

plot_acf(bbri['Close'], color = 'dodgerblue', ax = ax2)
ax2.set_title('Autocorrelation', size = 20)
ax2.grid()

plt.show()

# %% [markdown]
# Kita akan menentukan banyaknya diferensiasi yang diperlukan dengan menggunakan _ndiffs_ dari package pmdarima.

# %%
ndiffs(bbri['Close'], test = 'adf')
# Out:
# 0

# %% [markdown]
# Karena nilai _ndiifs_ adalah 0, berarti data harga `Close` BBRI yang kita miliki tidak perlu didiferensiasi.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,4))
bbri['Close'].plot(color = 'steelblue', ax = ax1)
ax1.set_title('BBRI Close Price', size = 20)
ax1.grid()

plot_pacf(bbri['Close'], color = 'dodgerblue', ax = ax2)
ax2.set_title('Partial Autocorrelation', size = 20)
ax2.grid()

plt.show()

# %% [markdown]
# Dari plot PACF, kita pilih nilai p = 1 (nilai yang melebihi area yang diarsir/ significance line) dan nilai q = 8 (nilai yang berada di dalam significance line).
#
# Sehingga kita dapatkan **p = 1**, **d = 0**, dan **q = 8**.

# %% [markdown]
# **Train Test Split**

# %%
bbri_arima_train = bbri['Close'][:bbri_train_len]
bbri_arima_valid = bbri['Close'][bbri_train_len:]

# %% [markdown]
# **Model Fitting and Evaluation**

# %%
bbri_arima = ARIMA(bbri_arima_train, order = (1, 0, 8))
bbri_arima_result = bbri_arima.fit()

bbri_arima_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  969
# Model:                 ARIMA(1, 0, 8)   Log Likelihood               -6404.301
# Date:                Sun, 18 Apr 2021   AIC                          12830.601
# Time:                        21:44:07   BIC                          12884.240
# Sample:                             0   HQIC                         12851.019
#                                 - 969
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3146.4869    838.979      3.750      0.000    1502.119    4790.855
# ar.L1          0.9994      0.002    585.304      0.000       0.996       1.003
# ma.L1         -0.2800      0.029     -9.719      0.000      -0.336      -0.224
# ma.L2         -0.2129      0.031     -6.798      0.000      -0.274      -0.151
# ma.L3         -0.1396      0.032     -4.358      0.000      -0.202      -0.077
# ma.L4         -0.1146      0.033     -3.487      0.000      -0.179      -0.050
# ma.L5         -0.0604      0.036     -1.668      0.095      -0.131       0.011
# ma.L6         -0.0086      0.036     -0.240      0.811      -0.079       0.062
# ma.L7         -0.0165      0.038     -0.437      0.662      -0.091       0.058
# ma.L8          0.0045      0.035      0.130      0.896      -0.063       0.073
# sigma2      3.251e+04   1079.124     30.130      0.000    3.04e+04    3.46e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               452.28
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.06   Skew:                            -0.40
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
steps = len(bbri_arima_valid)

fc = bbri_arima_result.forecast(steps)
fc_series = pd.DataFrame(fc)

# %%
plt.figure(figsize = (10,5), dpi = 100)
plt.plot(bbri_arima_train, label = 'Train Data', color = 'steelblue')
plt.plot(bbri_arima_valid, label = 'Actual Stock Price', color = 'lightseagreen')
plt.plot(fc_series, label = 'Predicted Stock Price', color = 'crimson')
plt.title('BBRI Prediction: ARIMA Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper left', fontsize = 8)
plt.show()

# %%
mse = mean_squared_error(bbri_arima_valid, fc)
print(f'MSE: {mse}')
rmse = math.sqrt(mean_squared_error(bbri_arima_valid, fc))
print(f'RMSE: {rmse}')
# Out:
# MSE: 896730.0954665006
# RMSE: 946.9583388230449

# %% [markdown]
# **Auto ARIMA Tuning**

# %%
model_autoARIMA = auto_arima(bbri_arima_train, start_p = 0, start_q = 0,
                      test = 'adf',       # use adftest to find optimal 'd'
                      max_p = 15, max_q = 15, # maximum p and q
                      m = 1,              # frequency of series
                      d = None,           # let model determine 'd'
                      seasonal = False,   # No Seasonality
                      start_P = 0, 
                      D = 0, 
                      trace = True,
                      error_action = 'ignore',  
                      suppress_warnings = True, 
                      stepwise = True)

print(model_autoARIMA.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18412.362, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=17161.651, Time=0.82 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=12933.557, Time=0.77 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=12868.696, Time=2.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=12823.698, Time=1.88 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.18 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=12824.559, Time=2.54 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=3.29 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=12832.186, Time=2.09 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=inf, Time=0.23 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=inf, Time=4.02 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=12836.713, Time=3.95 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0]
# Total fit time: 22.143 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  969
# Model:               SARIMAX(3, 0, 1)   Log Likelihood               -6406.849
# Date:                Sun, 18 Apr 2021   AIC                          12823.698
# Time:                        21:44:31   BIC                          12848.079
# Sample:                             0   HQIC                         12832.979
#                                 - 969
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6555      0.031     53.935      0.000       1.595       1.716
# ar.L2         -0.7060      0.053    -13.263      0.000      -0.810      -0.602
# ar.L3          0.0504      0.032      1.571      0.116      -0.012       0.113
# ma.L1         -0.9331      0.015    -61.588      0.000      -0.963      -0.903
# sigma2      3.217e+04   1.53e-07   2.11e+11      0.000    3.22e+04    3.22e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):               463.31
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.06   Skew:                            -0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.43e+27. Standard errors may be unstable.

# %%
bbri_arima_tuned = ARIMA(bbri_arima_train, order = (3, 0, 1))
bbri_arima_tuned_result = bbri_arima_tuned.fit()

bbri_arima_tuned_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  969
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -6405.481
# Date:                Sun, 18 Apr 2021   AIC                          12822.963
# Time:                        21:44:34   BIC                          12852.221
# Sample:                             0   HQIC                         12834.100
#                                 - 969
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3146.4950    894.447      3.518      0.000    1393.410    4899.580
# ar.L1          1.6549      0.032     51.271      0.000       1.592       1.718
# ar.L2         -0.7056      0.054    -13.077      0.000      -0.811      -0.600
# ar.L3          0.0504      0.032      1.570      0.116      -0.013       0.113
# ma.L1         -0.9326      0.016    -56.583      0.000      -0.965      -0.900
# sigma2      3.217e+04   1039.246     30.952      0.000    3.01e+04    3.42e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):               456.17
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.06   Skew:                            -0.41
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
steps = len(bbri_arima_valid)

fc_tuned = bbri_arima_tuned_result.forecast(steps, alpha = 0.05)
fc_series_tuned = pd.DataFrame(fc_tuned)

# %%
plt.figure(figsize = (10,5), dpi = 100)
plt.plot(bbri_arima_train, label = 'Train Data', color = 'steelblue')
plt.plot(bbri_arima_valid, label = 'Actual Stock Price', color = 'lightseagreen')
plt.plot(fc_series_tuned, label = 'Predicted Stock Price', color = 'crimson')
plt.title('BBRI Prediction: ARIMA Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper left', fontsize = 8)

plt.savefig('BBRI ARIMA.png')
plt.show()

# %%
mse_tuned = mean_squared_error(bbri_arima_valid, fc_tuned)
print(f'MSE: {mse_tuned}')
rmse_tuned = math.sqrt(mean_squared_error(bbri_arima_valid, fc_tuned))
print(f'RMSE: {rmse_tuned}')
# Out:
# MSE: 900842.4705299708
# RMSE: 949.1272151455624

# %% [markdown]
# **Result Comparison**

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
arima_compare = {'Evaluation Method': ['MSE', 'RMSE'], 'Manual Tuning' : [mse, rmse], 'Auto ARIMA Tuning' : [mse_tuned, rmse_tuned]}
pd.DataFrame(arima_compare)
# Out:
#   Evaluation Method  Manual Tuning  Auto ARIMA Tuning
# 0               MSE      896730.10          900842.47
# 1              RMSE         946.96             949.13

# %%
print(f'Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BBRI (validation price mean) adalah {round(rmse/ bbri_arima_valid.mean(), 5)}.')
print(f'Rasio RMSE (Auto ARIMA Tuning) dengan rata-rata harga saham BBRI (validation price mean) adalah {round(rmse_tuned/ bbri_arima_valid.mean(), 5)}.')
# Out:
# Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BBRI (validation price mean) adalah 0.26891.
# Rasio RMSE (Auto ARIMA Tuning) dengan rata-rata harga saham BBRI (validation price mean) adalah 0.26952.

# %% [markdown]
# Prediksi harga saham BBRI menggunakan model ARIMA dengan Manual Tuning memberikan hasil prediksi yang paling baik.

# %% [markdown]
# #### B.2. LSTM Model

# %%
bbri_array = bbri.filter(['Close']).values
bbri_array.shape
# Out:
# (1211, 1)

# %% [markdown]
# **Feature Engineering**

# %%
scaler = MinMaxScaler()
bbri_scaled = scaler.fit_transform(bbri_array)

# %% [markdown]
# **Data Splitting**

# %%
bbri_lstm_train = bbri_scaled[0:bbri_train_len, :]

bbri_lstm_x_train, bbri_lstm_y_train = [], []

for i in range(51, bbri_train_len):
    bbri_lstm_x_train.append(bbri_lstm_train[i-51:i, :])
    bbri_lstm_y_train.append(bbri_lstm_train[i, :])

# %% [markdown]
# LSTM menerima input data dalam bentuk 3D array, sehingga training data yang akan kita fit ke dalam model harus berbentuk array.

# %%
bbri_lstm_x_train, bbri_lstm_y_train = np.array(bbri_lstm_x_train), np.array(bbri_lstm_y_train)

# %%
print(f'Shape of x train: {bbri_lstm_x_train.shape}')
print(f'Shape of y train: {bbri_lstm_y_train.shape}')
# Out:
# Shape of x train: (918, 51, 1)
# Shape of y train: (918, 1)

# %% [markdown]
# **Model Fitting**

# %% [markdown]
# Dalam LSTM, terdapat beberapa parameter yang perlu ditentukan terlebih dahulu, yaitu:
# - **Hidden Layer** : banyaknya jumlah neuron yang akan digunakan dalam model
# - **Dropout** : besarnya peluang model 'melupakan' informasi yang kurang penting dari neuron sebelumnya (saya menggunakan 0.2)
# - **History Points** : banyaknya data yang digunakan dalam training untuk satu kali iterasi (saya membagi data training yang totalnya berjumlah 969 data ke dalam 17 iterasi, dengan masing-masing 51 history points per iterasi)
# - **Feature Number** : banyaknya feature yang digunakan (dalam hal ini hanya ada 1 feature)
# - **Optimizer** (biasanya digunakan optimizer _Adam_)

# %%
bbri_lstm = Sequential()
bbri_lstm.add(LSTM(50, return_sequences = False, input_shape = (bbri_lstm_x_train.shape[1], 1)))
bbri_lstm.add(Dropout(0.2))
bbri_lstm.add(Dense(bbri_lstm_y_train.shape[1]))

bbri_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# Jumlah batch size dan epoch yang umumnya digunakan untuk data kecil (ukuran data masih berjumlah ribuan) adalah 32 dan 100.

# %%
bbri_lstm.fit(bbri_lstm_x_train, bbri_lstm_y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 6s 34ms/step - loss: 0.1600
# Epoch 2/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0161
# Epoch 3/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0113
# Epoch 4/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0133
# Epoch 5/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0111
# Epoch 6/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0105
# Epoch 7/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0113
# Epoch 8/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0097: 0s - los
# Epoch 9/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0098
# Epoch 10/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0103
# Epoch 11/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0093
# Epoch 12/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0107
# Epoch 13/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0110
# Epoch 14/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0089
# Epoch 15/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0081
# Epoch 16/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0088
# Epoch 17/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0093
# Epoch 18/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0087
# Epoch 19/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0090
# Epoch 20/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0084: 0s - los
# Epoch 21/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0079
# Epoch 22/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0076
# Epoch 23/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0085
# Epoch 24/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0084
# Epoch 25/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0089
# Epoch 26/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0077
# Epoch 27/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0084
# Epoch 28/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0079
# Epoch 29/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0080
# Epoch 30/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0079
# Epoch 31/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0068
# Epoch 32/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0074
# Epoch 33/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0075
# Epoch 34/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0078
# Epoch 35/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0070
# Epoch 36/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0074
# Epoch 37/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0067
# Epoch 38/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0070
# Epoch 39/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0070
# Epoch 40/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0073: 0s - loss: 0.0
# Epoch 41/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0075
# Epoch 42/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0070
# Epoch 43/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0071
# Epoch 44/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0075
# Epoch 45/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0067
# Epoch 46/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0076
# Epoch 47/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0066
# Epoch 48/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0063
# Epoch 49/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0062
# Epoch 50/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0065
# Epoch 51/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0069
# Epoch 52/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0059
# Epoch 53/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0068
# Epoch 54/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0063
# Epoch 55/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0057
# Epoch 56/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0064
# Epoch 57/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0064
# Epoch 58/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0063
# Epoch 59/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0062
# Epoch 60/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0064
# Epoch 61/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0058
# Epoch 62/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0060
# Epoch 63/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0059
# Epoch 64/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0060
# Epoch 65/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0069
# Epoch 66/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0063
# Epoch 67/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0055
# Epoch 68/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0059
# Epoch 69/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0060
# Epoch 70/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0055
# Epoch 71/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0055
# Epoch 72/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0059
# Epoch 73/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0057
# Epoch 74/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0061
# Epoch 75/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0060
# Epoch 76/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0053
# Epoch 77/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0063
# Epoch 78/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0055
# Epoch 79/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0051
# Epoch 80/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0059
# Epoch 81/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0056
# Epoch 82/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0057
# Epoch 83/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0056
# Epoch 84/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0059
# Epoch 85/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0052
# Epoch 86/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0053
# Epoch 87/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0061
# Epoch 88/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0051
# Epoch 89/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0061
# Epoch 90/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0055
# Epoch 91/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0058
# Epoch 92/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0053
# Epoch 93/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0057
# Epoch 94/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0048
# Epoch 95/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0050
# Epoch 96/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0047
# Epoch 97/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0056
# Epoch 98/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0055
# Epoch 99/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0049
# Epoch 100/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0056

# %% [markdown]
# **Predictions**

# %%
bbri_lstm_test = bbri_scaled[bbri_train_len - 51:, :]
bbri_lstm_x_test = []
bbri_lstm_y_test = bbri_array[bbri_train_len:, :]

for i in range(51, len(bbri_lstm_test)):
    bbri_lstm_x_test.append(bbri_lstm_test[i-51:i, :])

# %%
bbri_lstm_x_test = np.array(bbri_lstm_x_test)

# %%
bbri_pred = bbri_lstm.predict(bbri_lstm_x_test)
bbri_pred = scaler.inverse_transform(bbri_pred)

# %% [markdown]
# **Model Evaluation**

# %%
bbri_lstm_train = bbri[:bbri_train_len]
bbri_lstm_valid = bbri[bbri_train_len:]
bbri_lstm_valid['Predictions'] = bbri_pred

plt.figure(figsize = (10,5), dpi = 100)

plt.plot(bbri_lstm_train['Close'], label = 'Train Data', color = 'steelblue')
plt.plot(bbri_lstm_valid['Close'], label = 'Actual Stock Price', color = 'teal')
plt.plot(bbri_lstm_valid['Predictions'], label = 'Predicted Stock Price', color = 'crimson')

plt.title('BBRI Prediction: LSTM Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper left', fontsize = 8)

plt.savefig('BBRI LSTM.png')
plt.show()

# %%
mse = mean_squared_error(bbri_pred, bbri_lstm_y_test)
print(f'MSE: {mse}')
rmse = math.sqrt(mean_squared_error(bbri_pred, bbri_lstm_y_test))
print(f'RMSE: {rmse}')
# Out:
# MSE: 222014.95970860025
# RMSE: 471.184634414791

# %% [markdown]
# **Manual Tuning**

# %% [markdown]
# Saya akan menentukan banyaknya jumlah neuron yang akan digunakan pada LSTM berdasarkan rumus berikut.

# %%
display.Image('./layer_formula.png', width = 600)

# %% [markdown]
# Referensi: https://towardsdatascience.com/choosing-the-right-hyperparameters-for-a-simple-lstm-using-keras-f8e9ed76f046

# %% [markdown]
# Dengan parameter:
# - Jumlah input adalah 51.
# - Jumlah output adalah 1
# - Jumlah sampel adalah 969 (sebanyak training data)
# - Nilai alpha yang saya gunakan adalah 2
#
# Sehingga diperoleh jumlah layer sebanyak 10 layer.

# %%
bbri_lstm_tuned = Sequential()
bbri_lstm_tuned.add(LSTM(10, return_sequences = False, input_shape = (bbri_lstm_x_train.shape[1], 1)))
bbri_lstm_tuned.add(Dropout(0.2))
bbri_lstm_tuned.add(Dense(bbri_lstm_y_train.shape[1]))

bbri_lstm_tuned.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
bbri_lstm_tuned.fit(bbri_lstm_x_train, bbri_lstm_y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 8s 31ms/step - loss: 0.1840
# Epoch 2/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0540
# Epoch 3/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0279
# Epoch 4/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0225
# Epoch 5/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0168
# Epoch 6/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0178
# Epoch 7/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0175
# Epoch 8/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0147
# Epoch 9/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0167
# Epoch 10/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0175
# Epoch 11/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0152
# Epoch 12/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0161
# Epoch 13/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0147
# Epoch 14/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0136
# Epoch 15/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0142
# Epoch 16/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0135
# Epoch 17/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0138
# Epoch 18/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0139
# Epoch 19/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0158
# Epoch 20/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0126
# Epoch 21/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0144
# Epoch 22/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0118
# Epoch 23/100
# 29/29 [==============================] - ETA: 0s - loss: 0.0125- ETA: 0s - los - 1s 29ms/step - loss: 0.0126
# Epoch 24/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0108
# Epoch 25/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0121
# Epoch 26/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0109
# Epoch 27/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0116
# Epoch 28/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0129
# Epoch 29/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0109
# Epoch 30/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0110
# Epoch 31/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0123: 0s - loss: 0.012
# Epoch 32/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0119
# Epoch 33/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0100
# Epoch 34/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0123
# Epoch 35/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0100: 0s - loss: 0.010
# Epoch 36/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0113
# Epoch 37/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0111
# Epoch 38/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0107: 0s - loss: 0.0
# Epoch 39/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0103
# Epoch 40/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0108
# Epoch 41/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0098
# Epoch 42/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0115
# Epoch 43/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0100
# Epoch 44/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0112
# Epoch 45/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0091
# Epoch 46/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0104
# Epoch 47/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0091: 0s - loss:
# Epoch 48/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0093: 0s - loss: 0.0
# Epoch 49/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0095
# Epoch 50/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0099
# Epoch 51/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0088
# Epoch 52/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0103
# Epoch 53/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0090
# Epoch 54/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0092: 0s - los
# Epoch 55/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0097
# Epoch 56/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0092
# Epoch 57/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0093
# Epoch 58/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0097
# Epoch 59/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0088
# Epoch 60/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0094: 0s - loss:
# Epoch 61/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0087
# Epoch 62/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0088
# Epoch 63/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0082
# Epoch 64/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0071
# Epoch 65/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0080
# Epoch 66/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0080
# Epoch 67/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0083
# Epoch 68/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0085
# Epoch 69/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0085
# Epoch 70/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0085: 0s - loss: 0. - ETA: 0s - loss: 0
# Epoch 71/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0083
# Epoch 72/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0091
# Epoch 73/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0083
# Epoch 74/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0079
# Epoch 75/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0089: 0s - loss: 0.00
# Epoch 76/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0073
# Epoch 77/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0089
# Epoch 78/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0075: 0s - loss: 0.007
# Epoch 79/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0073
# Epoch 80/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0080: 0s - l
# Epoch 81/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0080
# Epoch 82/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0080
# Epoch 83/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0072
# Epoch 84/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0075
# Epoch 85/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0076
# Epoch 86/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0072
# Epoch 87/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0074
# Epoch 88/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0077
# Epoch 89/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0069
# Epoch 90/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0072
# Epoch 91/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0070
# Epoch 92/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0074
# Epoch 93/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0068
# Epoch 94/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0068
# Epoch 95/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0080
# Epoch 96/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0070
# Epoch 97/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0071
# Epoch 98/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0069
# Epoch 99/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0077: 0s - loss
# Epoch 100/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0077

# %%
bbri_pred_tuned = bbri_lstm_tuned.predict(bbri_lstm_x_test)
bbri_pred_tuned = scaler.inverse_transform(bbri_pred_tuned)

# %% [markdown]
# **Model Evaluation**

# %%
bbri_lstm_train = bbri[:bbri_train_len]
bbri_lstm_valid = bbri[bbri_train_len:]
bbri_lstm_valid['Predictions'] = bbri_pred_tuned

plt.figure(figsize = (10,5), dpi = 100)

plt.plot(bbri_lstm_train['Close'], label = 'Train Data', color = 'steelblue')
plt.plot(bbri_lstm_valid['Close'], label = 'Actual Stock Price', color = 'teal')
plt.plot(bbri_lstm_valid['Predictions'], label = 'Predicted Stock Price', color = 'crimson')

plt.title('BBRI Prediction: LSTM Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper left', fontsize = 8)

plt.show()

# %%
mse_tuned = mean_squared_error(bbri_pred_tuned, bbri_lstm_y_test)
print(f'MSE: {mse_tuned}')
rmse_tuned = math.sqrt(mean_squared_error(bbri_pred_tuned, bbri_lstm_y_test))
print(f'RMSE: {rmse_tuned}')
# Out:
# MSE: 253820.22933198744
# RMSE: 503.80574563217067

# %% [markdown]
# **Result Comparison**

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
lstm_compare = {'Evaluation Method': ['MSE', 'RMSE'], 'Random Parameter' : [mse, rmse], 'Manual Tuning' : [mse_tuned, rmse_tuned]}
pd.DataFrame(lstm_compare)
# Out:
#   Evaluation Method  Random Parameter  Manual Tuning
# 0               MSE         222014.96      253820.23
# 1              RMSE            471.18         503.81

# %%
rmse_ratio = rmse/ bbri_lstm_valid['Close'].mean()
rmse_tuned_ratio = rmse_tuned/ bbri_lstm_valid['Close'].mean()

# %%
print(f'Rasio RMSE (Random Parameter) dengan rata-rata harga saham BBRI (validation price mean) adalah {round(rmse_ratio, 5)}.')
print(f'Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BBRI (validation price mean) adalah {round(rmse_tuned_ratio, 5)}.')
# Out:
# Rasio RMSE (Random Parameter) dengan rata-rata harga saham BBRI (validation price mean) adalah 0.1338.
# Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BBRI (validation price mean) adalah 0.14307.

# %% [markdown]
# Prediksi harga saham BBRI menggunakan model LSTM dengan random parameter memberikan hasil prediksi yang paling baik.

# %% [markdown]
# </br>

# %% [markdown]
# ### 5. Deployment

# %% [markdown]
# Model **LSTM** dengan random parameter memberikan nilai **RMSE yang paling kecil** (nilai prediksinya baik dan mendekati harga saham sesungguhnya). Oleh karena itu, saya akan menyimpan model tersebut untuk digunakan dalam deployment selanjutnya.

# %%
bbri_lstm.save('bbri_lstm_model.h5')

# %% [markdown]
# **Forecasting Future Prices**

# %%
bbri_lstm = load_model('bbri_lstm_model.h5')

# %%
bbri_scaled.shape
# Out:
# (1211, 1)

# %%
# Predict List

fit_new = bbri_scaled[len(bbri_scaled) - 51:, :]
steps = 246

new_data = []
new_result = []

for i in range(steps):
    new_data.clear()
    new_data.append(fit_new[i:])

    new_data = np.array(new_data)
    new_data = np.reshape(new_data, (new_data.shape[0], new_data.shape[1], 1))

    result = bbri_lstm.predict(new_data)
    new_result.append(scaler.inverse_transform(result))
    fit_new = np.append(fit_new, result)
    new_data = list(new_data)

# %% [markdown]
# Saya memilih _steps_ sebesar 246, sesuai dengan banyaknya hari perdagangan bursa di Indonesia untuk tahun 2021.

# %%
new_result = np.array(new_result)
new_result = np.reshape(new_result, (new_result.shape[0]))
new_result = pd.DataFrame(new_result)

# %%
new_result.to_csv('prediction_bbri.csv')

# %%
new = pd.DataFrame(bbri_array)
new = new.append(new_result, ignore_index = True)
new.columns = ['Price']

# %%
plt.figure(figsize = (10,5), dpi = 100)

plt.plot(new[:len(bbri)], label = 'Actual Price', color = 'steelblue')
plt.plot(new[len(bbri) : ], label = 'Predicted Stock Price', color = 'gold')

plt.title('BBRI Prediction 2021', size = 20)
plt.xlabel('Time')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper left', fontsize = 8)

plt.show()

# %% [markdown]
# Data yang saya gunakan untuk memprediksi harga saham 2021 merupakan nilai prediksi dari model LSTM yang digunakan berulang-ulang (tidak menambahkan data baru).
#
# Hasil percobaan yang saya dapatkan adalah, semakin besar nilai _steps_ maka hasil prediksi akan konvergen ke suatu nilai tertentu. Hal ini merupakan kelemahan dari model LSTM. Walaupun LSTM dapat memodelkan pergerakan harga saham dengan sangat baik (dibandingkan dengan model ARIMA), namun model LSTM kurang ideal apabila kita ingin memprediksi harga saham jangka panjang (nilai _steps_ besar). Pergerakan harga saham sesungguhnya kurang tercerminkan, namun kita masih bisa memprediksi trend pergerakan harga saham.
#
# Untuk menghasilkan prediksi yang akurat menggunakan LSTM, maka data yang digunakan untuk prediksi harus selalu diperbaharui dan _steps_ yang ditentukan tidak boleh terlalu besar.

# %%
buy_price = new['Price'][1]
price_5 = new['Price'][len(bbri) + 5]
price_30 = new['Price'][len(bbri) + 30]
price_60 = new['Price'][len(bbri) + 60]
price_90 = new['Price'][len(bbri) + 90]
price_120 = new['Price'][len(bbri) + 120]
price_end = new['Price'].iloc[-1]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
future_prices = {'Description': ['Buy Price', 'Prediction 2021 (1 Week)', 'Prediction 2021 (1 Month)', 'Prediction 2021 (2 Months)', 'Prediction 2021 (3 Months)', 'Prediction 2021 (4 Months)', 'Prediction 2021 (End of 2021)'],
                'Price' : [buy_price, price_5, price_30, price_60, price_90, price_120, price_end],
                'Return': ['-', (price_5-buy_price)/ buy_price, (price_30-buy_price)/ buy_price, (price_60-buy_price)/ buy_price, (price_90-buy_price)/ buy_price, (price_120-buy_price)/ buy_price, (price_end-buy_price)/ buy_price]}
pd.DataFrame(future_prices)
# Out:
#                      Description   Price Return
# 0                      Buy Price 2140.00      -
# 1       Prediction 2021 (1 Week) 3795.72   0.77
# 2      Prediction 2021 (1 Month) 3546.10   0.66
# 3     Prediction 2021 (2 Months) 3132.24   0.46
# 4     Prediction 2021 (3 Months) 2782.53   0.30
# 5     Prediction 2021 (4 Months) 2527.28   0.18
# 6  Prediction 2021 (End of 2021) 2437.42   0.14

# %% [markdown]
# Untuk tahun 2021, nampaknya harga saham BBRI diprediksi akan mengalami penurunan hingga ke IDR 2400 dengan rasio return 0.14. Trader/ investor dapat melakukan cut-loss (menjual aset yang dimiliki) untuk mengantisipasi kerugian lebih besar.
