# %% [markdown]
# ## Final Project: Prediksi Harga Saham Bank di Indonesia

# %% [markdown]
# **Karina Anggraeni - JCDSAH BSD** </br>
# Dataset diambil dari aplikasi Neo HOTS (Mirae Asset Sekuritas)
#
# Data harga saham bank yang digunakan dalam dataset ini adalah data terhadap bank swasta nasional, bank swasta asing, dan bank milik negara, yaitu:
# - Bank Central Asia (BBCA) dan Bank Mega (MEGA) - swasta nasional
# - Bank Woori Saudara (SDRA) dan MayBank (BNII) - swasta asing
# - Bank Rakyat Indonesia (BRII) dan Bank Mandiri (BMRI) - negara

# %% [markdown]
# ### [PART 4: Stock Price Prediction - BNII]

# %% [markdown]
# ### 4. Modeling and Evaluation

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

import os
from statsmodels.tsa.stattools import adfuller
from IPython.core.debugger import set_trace
from pmdarima.arima.utils import ndiffs
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.models import load_model

from IPython import display

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### C. BNII Stock Prediction

# %%
bnii = pd.read_csv('../Datasets/df_bnii.csv', index_col = 'Date')

# %%
bnii_train_len = math.ceil(len(bnii)*0.8)
bnii_train_len
# Out:
# 969

# %% [markdown]
# #### C.1. ARIMA Model

# %% [markdown]
# **ADF Stationary Test**

# %% [markdown]
# Augumented Dickey Fuller Test (ADF Test) digunakan untuk memeriksa stationer/ tidaknya suatu data. Test ini biasanya digunakan dalam ARIMA untuk time-series karena model ARIMA akan bekerja lebih baik pada data yang bersifat stationer.

# %%
bnii_adf = adfuller(bnii)

print(f'ADF Statistics: {bnii_adf[0]}')

if bnii_adf[1] > 0.05:
    print(f'p-value: {bnii_adf[1]}, data is stationary.')
else:
    print(f'p-value: {bnii_adf[1]}, data is non-stationary.')
# Out:
# ADF Statistics: -1.742452477867661
# p-value: 0.4093829883477105, data is stationary.

# %% [markdown]
# Karena nilai p-value dari ADF Test terhadap BBRI melebihi 0.05 (p-value > 0.05), maka dapat disimpulkan data yang kita miliki tidak stationer.

# %% [markdown]
# **Manual Parameter Tuning**

# %% [markdown]
# Pada model ARIMA, terdapat 3 jenis parameter yang dibutuhkan ketika melakukan modeling, yaitu: </br>
# - **p** menyatakan nilai variabel AR (Auto Regressive Variable/ Lag Variable) atau berapa banyak data periode sebelumnya yang akan digunakan dalam feature </br>
# - **d** menyatakan nilai variabel I (Integrated Variable) atau berapa banyak diferensiasi yang perlu dilakukan agar data time-series menjadi stationer </br>
# - **p** menyatakan nilai variabel MA (Moving Average Variable)
#
# Nilai p, d, dan q dapat kita estimasi menggunakan plot ACF dan  PACF.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,4))
bnii['Close'].plot(color = 'steelblue', ax = ax1)
ax1.set_title('BNII Close Price', size = 20)
ax1.grid()

plot_acf(bnii['Close'], color = 'dodgerblue', ax = ax2)
ax2.set_title('Autocorrelation', size = 20)
ax2.grid()

plt.show()

# %% [markdown]
# Kita akan menentukan banyaknya diferensiasi yang diperlukan dengan menggunakan _ndiffs_ dari package pmdarima.

# %%
ndiffs(bnii['Close'], test = 'adf')
# Out:
# 0

# %% [markdown]
# Karena nilai _ndiifs_ adalah 0, berarti data harga `Close` BNII yang kita miliki tidak perlu didiferensiasi.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16,4))
bnii['Close'].plot(color = 'steelblue', ax = ax1)
ax1.set_title('BNII Close Price', size = 20)
ax1.grid()

plot_pacf(bnii['Close'], color = 'dodgerblue', ax = ax2)
ax2.set_title('Partial Autocorrelation', size = 20)
ax2.grid()

plt.show()

# %% [markdown]
# Dari plot PACF, kita pilih nilai p = 1 (nilai yang melebihi area yang diarsir/ significance line) dan nilai q = 8 (nilai yang berada di dalam significance line).
#
# Sehingga kita dapatkan **p = 1**, **d = 0**, dan **q = 8**.

# %% [markdown]
# **Train Test Split**

# %%
bnii_arima_train = bnii['Close'][:bnii_train_len]
bnii_arima_valid = bnii['Close'][bnii_train_len:]

# %% [markdown]
# **Model Fitting and Evaluation**

# %%
bnii_arima = ARIMA(bnii_arima_train, order = (1, 0, 8))
bnii_arima_result = bnii_arima.fit()

bnii_arima_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  969
# Model:                 ARIMA(1, 0, 8)   Log Likelihood               -4752.890
# Date:                Sun, 18 Apr 2021   AIC                           9527.780
# Time:                        21:43:51   BIC                           9581.419
# Sample:                             0   HQIC                          9548.198
#                                 - 969
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        265.5520     25.152     10.558      0.000     216.255     314.848
# ar.L1          0.9957      0.005    217.025      0.000       0.987       1.005
# ma.L1         -0.2731      0.030     -9.062      0.000      -0.332      -0.214
# ma.L2         -0.0487      0.040     -1.211      0.226      -0.128       0.030
# ma.L3         -0.2479      0.024    -10.444      0.000      -0.294      -0.201
# ma.L4         -0.2774      0.021    -13.040      0.000      -0.319      -0.236
# ma.L5         -0.0367      0.038     -0.972      0.331      -0.111       0.037
# ma.L6         -0.0387      0.036     -1.086      0.277      -0.108       0.031
# ma.L7          0.0521      0.037      1.423      0.155      -0.020       0.124
# ma.L8         -0.0030      0.036     -0.083      0.934      -0.073       0.067
# sigma2      1063.9909     25.489     41.743      0.000    1014.033    1113.949
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             13864.31
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.14   Skew:                             0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
steps = len(bnii_arima_valid)

fc = bnii_arima_result.forecast(steps)
fc_series = pd.DataFrame(fc)

# %%
plt.figure(figsize = (10,5), dpi = 100)
plt.plot(bnii_arima_train, label = 'Train Data', color = 'steelblue')
plt.plot(bnii_arima_valid, label = 'Actual Stock Price', color = 'lightseagreen')
plt.plot(fc_series, label = 'Predicted Stock Price', color = 'crimson')
plt.title('BNII Prediction: ARIMA Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper right', fontsize = 8)
plt.show()

# %%
mse = mean_squared_error(bnii_arima_valid, fc)
print(f'MSE: {mse}')
rmse = math.sqrt(mean_squared_error(bnii_arima_valid, fc))
print(f'RMSE: {rmse}')
# Out:
# MSE: 3594.8074428256405
# RMSE: 59.95671307556511

# %% [markdown]
# **Auto ARIMA Tuning**

# %%
model_autoARIMA = auto_arima(bnii_arima_train, start_p = 0, start_q = 0,
                      test = 'adf',       # use adftest to find optimal 'd'
                      max_p = 10, max_q = 10, # maximum p and q
                      m = 1,              # frequency of series
                      d = None,           # let model determine 'd'
                      seasonal = False,   # No Seasonality
                      start_P = 0, 
                      D = 0, 
                      trace = True,
                      error_action = 'ignore',  
                      suppress_warnings = True, 
                      stepwise = True)

print(model_autoARIMA.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=13621.054, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=12460.967, Time=0.25 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=9690.193, Time=0.36 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=9689.203, Time=0.70 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=9691.086, Time=0.61 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=1.84 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=9692.127, Time=0.41 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.66 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=9681.870, Time=1.80 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=9662.887, Time=3.09 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=9540.232, Time=2.84 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=9536.413, Time=2.77 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=9529.143, Time=3.27 sec
#  ARIMA(6,0,0)(0,0,0)[0]             : AIC=inf, Time=0.95 sec
#  ARIMA(7,0,1)(0,0,0)[0]             : AIC=9533.518, Time=3.76 sec
#  ARIMA(6,0,2)(0,0,0)[0]             : AIC=inf, Time=4.56 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=9531.172, Time=1.51 sec
#  ARIMA(7,0,0)(0,0,0)[0]             : AIC=inf, Time=1.17 sec
#  ARIMA(7,0,2)(0,0,0)[0]             : AIC=inf, Time=5.63 sec
#  ARIMA(6,0,1)(0,0,0)[0] intercept   : AIC=9572.172, Time=2.91 sec
#
# Best model:  ARIMA(6,0,1)(0,0,0)[0]
# Total fit time: 41.387 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  969
# Model:               SARIMAX(6, 0, 1)   Log Likelihood               -4756.572
# Date:                Sun, 18 Apr 2021   AIC                           9529.143
# Time:                        21:44:34   BIC                           9568.153
# Sample:                             0   HQIC                          9543.992
#                                 - 969
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6724      0.034     49.739      0.000       1.606       1.738
# ar.L2         -0.5339      0.062     -8.638      0.000      -0.655      -0.413
# ar.L3         -0.3140      0.070     -4.475      0.000      -0.452      -0.176
# ar.L4          0.0351      0.042      0.841      0.400      -0.047       0.117
# ar.L5          0.2422      0.038      6.346      0.000       0.167       0.317
# ar.L6         -0.1019      0.029     -3.554      0.000      -0.158      -0.046
# ma.L1         -0.9518      0.010    -92.690      0.000      -0.972      -0.932
# sigma2      1065.2288     19.479     54.686      0.000    1027.051    1103.407
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):             14693.93
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.13   Skew:                             1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
bnii_arima_tuned = ARIMA(bnii_arima_train, order = (6, 0, 1))
bnii_arima_tuned_result = bnii_arima_tuned.fit()

bnii_arima_tuned_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  969
# Model:                 ARIMA(6, 0, 1)   Log Likelihood               -4754.230
# Date:                Sun, 18 Apr 2021   AIC                           9526.460
# Time:                        21:44:39   BIC                           9570.347
# Sample:                             0   HQIC                          9543.166
#                                 - 969
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        265.3327     26.306     10.086      0.000     213.773     316.892
# ar.L1          1.6675      0.038     43.762      0.000       1.593       1.742
# ar.L2         -0.5316      0.066     -8.077      0.000      -0.661      -0.403
# ar.L3         -0.3089      0.073     -4.226      0.000      -0.452      -0.166
# ar.L4          0.0300      0.043      0.696      0.486      -0.054       0.114
# ar.L5          0.2441      0.039      6.222      0.000       0.167       0.321
# ar.L6         -0.1029      0.030     -3.439      0.001      -0.161      -0.044
# ma.L1         -0.9487      0.014    -68.891      0.000      -0.976      -0.922
# sigma2      1093.4823     26.827     40.760      0.000    1040.902    1146.063
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             14078.79
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.13   Skew:                             0.96
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
steps = len(bnii_arima_valid)

fc_tuned = bnii_arima_tuned_result.forecast(steps, alpha = 0.05)
fc_series_tuned = pd.DataFrame(fc_tuned)

# %%
plt.figure(figsize = (10,5), dpi = 100)
plt.plot(bnii_arima_train, label = 'Train Data', color = 'steelblue')
plt.plot(bnii_arima_valid, label = 'Actual Stock Price', color = 'lightseagreen')
plt.plot(fc_series_tuned, label = 'Predicted Stock Price', color = 'crimson')
plt.title('BNII Prediction: ARIMA Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper right', fontsize = 8)

plt.savefig('BNII ARIMA.png')
plt.show()

# %%
mse_tuned = mean_squared_error(bnii_arima_valid, fc_tuned)
print(f'MSE: {mse_tuned}')
rmse_tuned = math.sqrt(mean_squared_error(bnii_arima_valid, fc_tuned))
print(f'RMSE: {rmse_tuned}')
# Out:
# MSE: 3545.7546392432405
# RMSE: 59.54623950547373

# %% [markdown]
# **Result Comparison**

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
arima_compare = {'Evaluation Method': ['MSE', 'RMSE'], 'Manual Tuning' : [mse, rmse], 'Auto ARIMA Tuning' : [mse_tuned, rmse_tuned]}
pd.DataFrame(arima_compare)
# Out:
#   Evaluation Method  Manual Tuning  Auto ARIMA Tuning
# 0               MSE        3594.81            3545.75
# 1              RMSE          59.96              59.55

# %%
print(f'Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BNII (validation price mean) adalah {round(rmse/ bnii_arima_valid.mean(), 5)}.')
print(f'Rasio RMSE (Auto ARIMA Tuning) dengan rata-rata harga saham BNII (validation price mean) adalah {round(rmse_tuned/ bnii_arima_valid.mean(), 5)}.')
# Out:
# Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BNII (validation price mean) adalah 0.3067.
# Rasio RMSE (Auto ARIMA Tuning) dengan rata-rata harga saham BNII (validation price mean) adalah 0.3046.

# %% [markdown]
# Prediksi harga saham BNII menggunakan model ARIMA dengan Auto ARIMA Tuning memberikan hasil prediksi yang paling baik.

# %% [markdown]
# #### C.2. LSTM Model

# %%
bnii_array = bnii.filter(['Close']).values
bnii_array.shape
# Out:
# (1211, 1)

# %% [markdown]
# **Feature Engineering**

# %%
scaler = MinMaxScaler()
bnii_scaled = scaler.fit_transform(bnii_array)

# %% [markdown]
# **Data Splitting**

# %%
bnii_lstm_train = bnii_scaled[0:bnii_train_len, :]

bnii_lstm_x_train, bnii_lstm_y_train = [], []

for i in range(51, bnii_train_len):
    bnii_lstm_x_train.append(bnii_lstm_train[i-51:i, :])
    bnii_lstm_y_train.append(bnii_lstm_train[i, :])

# %% [markdown]
# LSTM menerima input data dalam bentuk 3D array, sehingga training data yang akan kita fit ke dalam model harus berbentuk array.

# %%
bnii_lstm_x_train, bnii_lstm_y_train = np.array(bnii_lstm_x_train), np.array(bnii_lstm_y_train)

# %%
print(f'Shape of x train: {bnii_lstm_x_train.shape}')
print(f'Shape of y train: {bnii_lstm_y_train.shape}')
# Out:
# Shape of x train: (918, 51, 1)
# Shape of y train: (918, 1)

# %% [markdown]
# **Model Fitting**

# %% [markdown]
# Dalam LSTM, terdapat beberapa parameter yang perlu ditentukan terlebih dahulu, yaitu:
# - **Hidden Layer** : banyaknya jumlah neuron yang akan digunakan dalam model
# - **Dropout** : besarnya peluang model 'melupakan' informasi yang kurang penting dari neuron sebelumnya (saya menggunakan 0.2)
# - **History Points** : banyaknya data yang digunakan dalam training untuk satu kali iterasi (saya membagi data training yang totalnya berjumlah 969 data ke dalam 17 iterasi, dengan masing-masing 51 history points per iterasi)
# - **Feature Number** : banyaknya feature yang digunakan (dalam hal ini hanya ada 1 feature)
# - **Optimizer** (biasanya digunakan optimizer _Adam_)

# %%
bnii_lstm = Sequential()
bnii_lstm.add(LSTM(50, return_sequences = False, input_shape = (bnii_lstm_x_train.shape[1], 1)))
bnii_lstm.add(Dropout(0.2))
bnii_lstm.add(Dense(bnii_lstm_y_train.shape[1]))

bnii_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# Jumlah batch size dan epoch yang umumnya digunakan untuk data kecil (ukuran data masih berjumlah ribuan) adalah 32 dan 100.

# %%
bnii_lstm.fit(bnii_lstm_x_train, bnii_lstm_y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 8s 32ms/step - loss: 0.1931
# Epoch 2/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0254
# Epoch 3/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0226
# Epoch 4/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0206
# Epoch 5/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0200
# Epoch 6/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0189
# Epoch 7/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0205
# Epoch 8/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0210
# Epoch 9/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0174
# Epoch 10/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0201
# Epoch 11/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0187
# Epoch 12/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0175
# Epoch 13/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0160
# Epoch 14/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0158
# Epoch 15/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0159
# Epoch 16/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0148
# Epoch 17/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0179
# Epoch 18/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0160
# Epoch 19/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0171
# Epoch 20/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0191
# Epoch 21/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0173
# Epoch 22/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0143
# Epoch 23/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0133
# Epoch 24/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0140
# Epoch 25/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0151
# Epoch 26/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0140
# Epoch 27/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0133
# Epoch 28/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0133
# Epoch 29/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0168
# Epoch 30/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0117
# Epoch 31/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0133
# Epoch 32/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0113
# Epoch 33/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0116
# Epoch 34/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0116
# Epoch 35/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0142
# Epoch 36/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0108
# Epoch 37/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0125
# Epoch 38/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0124
# Epoch 39/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0128
# Epoch 40/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0092
# Epoch 41/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0104
# Epoch 42/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0106
# Epoch 43/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0109
# Epoch 44/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0126
# Epoch 45/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0102
# Epoch 46/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0130
# Epoch 47/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0123
# Epoch 48/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0117
# Epoch 49/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0117
# Epoch 50/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0108
# Epoch 51/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0124
# Epoch 52/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0102
# Epoch 53/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0108
# Epoch 54/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0126
# Epoch 55/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0092
# Epoch 56/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0109
# Epoch 57/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0105
# Epoch 58/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0110
# Epoch 59/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0120
# Epoch 60/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0105
# Epoch 61/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0088
# Epoch 62/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0119
# Epoch 63/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0093
# Epoch 64/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0104
# Epoch 65/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0122
# Epoch 66/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0100
# Epoch 67/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0117
# Epoch 68/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0098
# Epoch 69/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0110
# Epoch 70/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0115
# Epoch 71/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0098
# Epoch 72/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0089
# Epoch 73/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0097
# Epoch 74/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0090
# Epoch 75/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0087
# Epoch 76/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0110
# Epoch 77/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0096
# Epoch 78/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0103
# Epoch 79/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0115
# Epoch 80/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0105
# Epoch 81/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0088
# Epoch 82/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0100
# Epoch 83/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0098
# Epoch 84/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0087
# Epoch 85/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0104
# Epoch 86/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0088
# Epoch 87/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0110
# Epoch 88/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0094
# Epoch 89/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0098
# Epoch 90/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0110
# Epoch 91/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0093
# Epoch 92/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0104
# Epoch 93/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0091
# Epoch 94/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0119
# Epoch 95/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0094: 0s
# Epoch 96/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0107
# Epoch 97/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0082
# Epoch 98/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0091
# Epoch 99/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0087
# Epoch 100/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0092

# %% [markdown]
# **Predictions**

# %%
bnii_lstm_test = bnii_scaled[bnii_train_len - 51:, :]
bnii_lstm_x_test = []
bnii_lstm_y_test = bnii_array[bnii_train_len:, :]

for i in range(51, len(bnii_lstm_test)):
    bnii_lstm_x_test.append(bnii_lstm_test[i-51:i, :])

# %%
bnii_lstm_x_test = np.array(bnii_lstm_x_test)

# %%
bnii_pred = bnii_lstm.predict(bnii_lstm_x_test)
bnii_pred = scaler.inverse_transform(bnii_pred)

# %% [markdown]
# **Model Evaluation**

# %%
bnii_lstm_train = bnii[:bnii_train_len]
bnii_lstm_valid = bnii[bnii_train_len:]
bnii_lstm_valid['Predictions'] = bnii_pred

plt.figure(figsize = (10,5), dpi = 100)

plt.plot(bnii_lstm_train['Close'], label = 'Train Data', color = 'steelblue')
plt.plot(bnii_lstm_valid['Close'], label = 'Actual Stock Price', color = 'teal')
plt.plot(bnii_lstm_valid['Predictions'], label = 'Predicted Stock Price', color = 'crimson')

plt.title('BNII Prediction: LSTM Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper right', fontsize = 8)

plt.savefig('BNII LSTM.png')
plt.show()

# %%
mse = mean_squared_error(bnii_pred, bnii_lstm_y_test)
print(f'MSE: {mse}')
rmse = math.sqrt(mean_squared_error(bnii_pred, bnii_lstm_y_test))
print(f'RMSE: {rmse}')
# Out:
# MSE: 681.9035392613314
# RMSE: 26.113282812801064

# %% [markdown]
# **Manual Tuning**

# %% [markdown]
# Saya akan menentukan banyaknya jumlah neuron yang akan digunakan pada LSTM berdasarkan rumus berikut.

# %%
display.Image('./layer_formula.png', width = 600)

# %% [markdown]
# Referensi: https://towardsdatascience.com/choosing-the-right-hyperparameters-for-a-simple-lstm-using-keras-f8e9ed76f046

# %% [markdown]
# Dengan parameter:
# - Jumlah input adalah 51.
# - Jumlah output adalah 1
# - Jumlah sampel adalah 969 (sebanyak training data)
# - Nilai alpha yang saya gunakan adalah 10
#
# Sehingga diperoleh jumlah layer sebanyak 2 layer.

# %%
bnii_lstm_tuned = Sequential()
bnii_lstm_tuned.add(LSTM(2, return_sequences = False, input_shape = (bnii_lstm_x_train.shape[1], 1)))
bnii_lstm_tuned.add(Dropout(0.2))
bnii_lstm_tuned.add(Dense(bnii_lstm_y_train.shape[1]))

bnii_lstm_tuned.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
bnii_lstm_tuned.fit(bnii_lstm_x_train, bnii_lstm_y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 9s 23ms/step - loss: 0.3501
# Epoch 2/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.2100
# Epoch 3/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1501
# Epoch 4/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0948
# Epoch 5/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0728
# Epoch 6/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0667
# Epoch 7/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0604
# Epoch 8/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0558
# Epoch 9/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0600
# Epoch 10/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0540
# Epoch 11/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0500
# Epoch 12/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0540
# Epoch 13/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0465
# Epoch 14/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0530
# Epoch 15/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0458: 0s - loss: 0.04
# Epoch 16/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0415
# Epoch 17/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0420
# Epoch 18/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0432
# Epoch 19/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0435
# Epoch 20/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0416
# Epoch 21/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0425: 0s - loss: 0.042
# Epoch 22/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0409
# Epoch 23/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0373
# Epoch 24/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0323
# Epoch 25/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0384
# Epoch 26/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0339
# Epoch 27/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0321
# Epoch 28/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0329
# Epoch 29/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0329
# Epoch 30/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0335
# Epoch 31/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0289
# Epoch 32/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0324
# Epoch 33/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0280
# Epoch 34/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0259
# Epoch 35/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0275
# Epoch 36/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0270
# Epoch 37/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0287
# Epoch 38/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0245
# Epoch 39/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0224
# Epoch 40/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0229
# Epoch 41/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0235
# Epoch 42/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0226
# Epoch 43/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0211
# Epoch 44/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0225
# Epoch 45/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0197
# Epoch 46/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0194
# Epoch 47/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0208
# Epoch 48/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0194
# Epoch 49/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0187
# Epoch 50/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0203
# Epoch 51/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0183
# Epoch 52/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0227
# Epoch 53/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0204
# Epoch 54/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0229: 0s - loss:
# Epoch 55/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0237: 0s - loss: 0
# Epoch 56/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0199
# Epoch 57/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0172
# Epoch 58/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0192
# Epoch 59/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0202
# Epoch 60/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0191
# Epoch 61/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0175
# Epoch 62/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0198
# Epoch 63/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0181
# Epoch 64/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0204: 0s - loss: 0.0
# Epoch 65/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0190
# Epoch 66/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0211
# Epoch 67/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0186
# Epoch 68/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0176
# Epoch 69/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0159
# Epoch 70/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0181
# Epoch 71/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0192
# Epoch 72/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0200
# Epoch 73/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0217
# Epoch 74/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0219
# Epoch 75/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0189
# Epoch 76/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0188
# Epoch 77/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0180: 0s - los
# Epoch 78/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0180
# Epoch 79/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0175
# Epoch 80/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0174
# Epoch 81/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0175
# Epoch 82/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0179
# Epoch 83/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0164
# Epoch 84/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0189: 0s - loss:
# Epoch 85/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0191
# Epoch 86/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0193
# Epoch 87/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0175
# Epoch 88/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0169
# Epoch 89/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0203
# Epoch 90/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0178
# Epoch 91/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0215
# Epoch 92/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0188
# Epoch 93/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0169
# Epoch 94/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0191
# Epoch 95/100
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0205
# Epoch 96/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0170
# Epoch 97/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0177
# Epoch 98/100
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0175
# Epoch 99/100
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0172: 0s -
# Epoch 100/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0168

# %%
bnii_pred_tuned = bnii_lstm_tuned.predict(bnii_lstm_x_test)
bnii_pred_tuned = scaler.inverse_transform(bnii_pred_tuned)

# %% [markdown]
# **Model Evaluation**

# %%
bnii_lstm_train = bnii[:bnii_train_len]
bnii_lstm_valid = bnii[bnii_train_len:]
bnii_lstm_valid['Predictions'] = bnii_pred_tuned

plt.figure(figsize = (10,5), dpi = 100)

plt.plot(bnii_lstm_train['Close'], label = 'Train Data', color = 'steelblue')
plt.plot(bnii_lstm_valid['Close'], label = 'Actual Stock Price', color = 'teal')
plt.plot(bnii_lstm_valid['Predictions'], label = 'Predicted Stock Price', color = 'crimson')

plt.title('BNII Prediction: LSTM Model', size = 20)
plt.xticks(ticks = [0, 200, 400, 600, 800, 1000, 1200])
plt.xlabel('Date')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper right', fontsize = 8)

plt.show()

# %%
mse_tuned = mean_squared_error(bnii_pred_tuned, bnii_lstm_y_test)
print(f'MSE: {mse_tuned}')
rmse_tuned = math.sqrt(mean_squared_error(bnii_pred_tuned, bnii_lstm_y_test))
print(f'RMSE: {rmse_tuned}')
# Out:
# MSE: 1573.0388238113287
# RMSE: 39.66155347198756

# %% [markdown]
# **Result Comparison**

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
lstm_compare = {'Evaluation Method': ['MSE', 'RMSE'], 'Random Parameter' : [mse, rmse], 'Manual Tuning' : [mse_tuned, rmse_tuned]}
pd.DataFrame(lstm_compare)
# Out:
#   Evaluation Method  Random Parameter  Manual Tuning
# 0               MSE            681.90        1573.04
# 1              RMSE             26.11          39.66

# %%
rmse_ratio = rmse/ bnii_lstm_valid['Close'].mean()
rmse_tuned_ratio = rmse_tuned/ bnii_lstm_valid['Close'].mean()

# %%
print(f'Rasio RMSE (Random Parameter) dengan rata-rata harga saham BNII (validation price mean) adalah {round(rmse_ratio, 5)}.')
print(f'Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BNII (validation price mean) adalah {round(rmse_tuned_ratio, 5)}.')
# Out:
# Rasio RMSE (Random Parameter) dengan rata-rata harga saham BNII (validation price mean) adalah 0.13358.
# Rasio RMSE (Manual Tuning) dengan rata-rata harga saham BNII (validation price mean) adalah 0.20288.

# %% [markdown]
# Prediksi harga saham BNII menggunakan model LSTM dengan random parameter memberikan hasil prediksi yang paling baik.

# %% [markdown]
# </br>

# %% [markdown]
# ### 5. Deployment

# %% [markdown]
# Model **LSTM** dengan random parameter memberikan nilai **RMSE yang paling kecil** (nilai prediksinya baik dan mendekati harga saham sesungguhnya). Oleh karena itu, saya akan menyimpan model tersebut untuk digunakan dalam deployment selanjutnya.

# %%
bnii_lstm.save('bnii_lstm_model.h5')

# %% [markdown]
# **Forecasting Future Prices**

# %%
bnii_lstm = load_model('bnii_lstm_model.h5')

# %%
bnii_scaled.shape
# Out:
# (1211, 1)

# %%
# Predict List

fit_new = bnii_scaled[len(bnii_scaled) - 51:, :]
steps = 246

new_data = []
new_result = []

for i in range(steps):
    new_data.clear()
    new_data.append(fit_new[i:])

    new_data = np.array(new_data)
    new_data = np.reshape(new_data, (new_data.shape[0], new_data.shape[1], 1))

    result = bnii_lstm.predict(new_data)
    new_result.append(scaler.inverse_transform(result))
    fit_new = np.append(fit_new, result)
    new_data = list(new_data)

# %% [markdown]
# Saya memilih _steps_ sebesar 246, sesuai dengan banyaknya hari perdagangan bursa di Indonesia untuk tahun 2021.

# %%
new_result = np.array(new_result)
new_result = np.reshape(new_result, (new_result.shape[0]))
new_result = pd.DataFrame(new_result)

# %%
new_result.to_csv('prediction_bnii.csv')

# %%
new = pd.DataFrame(bnii_array)
new = new.append(new_result, ignore_index = True)
new.columns = ['Price']

# %%
plt.figure(figsize = (10,5), dpi = 100)

plt.plot(new[:len(bnii)], label = 'Actual Price', color = 'steelblue')
plt.plot(new[len(bnii) : ], label = 'Predicted Stock Price', color = 'gold')

plt.title('BNII Prediction 2021', size = 20)
plt.xlabel('Time')
plt.ylabel('Stock Price (IDR)')
plt.legend(loc = 'upper right', fontsize = 8)

plt.show()

# %% [markdown]
# Data yang saya gunakan untuk memprediksi harga saham 2021 merupakan nilai prediksi dari model LSTM yang digunakan berulang-ulang (tidak menambahkan data baru).
#
# Hasil percobaan yang saya dapatkan adalah, semakin besar nilai _steps_ maka hasil prediksi akan konvergen ke suatu nilai tertentu. Hal ini merupakan kelemahan dari model LSTM. Walaupun LSTM dapat memodelkan pergerakan harga saham dengan sangat baik (dibandingkan dengan model ARIMA), namun model LSTM kurang ideal apabila kita ingin memprediksi harga saham jangka panjang (nilai _steps_ besar). Pergerakan harga saham sesungguhnya kurang tercerminkan, namun kita masih bisa memprediksi trend pergerakan harga saham.
#
# Untuk menghasilkan prediksi yang akurat menggunakan LSTM, maka data yang digunakan untuk prediksi harus selalu diperbaharui dan _steps_ yang ditentukan tidak boleh terlalu besar.

# %%
buy_price = new['Price'][1]
price_5 = new['Price'][len(bnii) + 5]
price_30 = new['Price'][len(bnii) + 30]
price_60 = new['Price'][len(bnii) + 60]
price_90 = new['Price'][len(bnii) + 90]
price_120 = new['Price'][len(bnii) + 120]
price_end = new['Price'].iloc[-1]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
future_prices = {'Description': ['Buy Price', 'Prediction 2021 (1 Week)', 'Prediction 2021 (1 Month)', 'Prediction 2021 (2 Months)', 'Prediction 2021 (3 Months)', 'Prediction 2021 (4 Months)', 'Prediction 2021 (End of 2021)'],
                'Price' : [buy_price, price_5, price_30, price_60, price_90, price_120, price_end],
                'Return': ['-', (price_5-buy_price)/ buy_price, (price_30-buy_price)/ buy_price, (price_60-buy_price)/ buy_price, (price_90-buy_price)/ buy_price, (price_120-buy_price)/ buy_price, (price_end-buy_price)/ buy_price]}
pd.DataFrame(future_prices)
# Out:
#                      Description  Price Return
# 0                      Buy Price 175.00      -
# 1       Prediction 2021 (1 Week) 256.07   0.46
# 2      Prediction 2021 (1 Month) 248.58   0.42
# 3     Prediction 2021 (2 Months) 279.18   0.60
# 4     Prediction 2021 (3 Months) 238.66   0.36
# 5     Prediction 2021 (4 Months) 257.88   0.47
# 6  Prediction 2021 (End of 2021) 240.03   0.37

# %% [markdown]
# Saham BNII menunjukkan trend sideways, dengan harga saham konvergen ke IDR 240 dan rasio return 0.37.
